# %%
# !pip install scipy

# %% [markdown]
# # Basic prog py

# %%
print ("delta 11")
# Out:
# delta 11

# %%
_input = input()
# Out:
# 115

# %%
print("u ntred: ",_input)
# Out:
# u ntred:  115

# %%
print("width: ")
_w = input()
print("height: ")
_h = input()
print("total pix: ")
print("_w * _h")
# Out:
# width:
# 5
# height:
# 4
# total pix:
# _w * _h

# %%
print("width: ")
_w = input()
print("height: ")
_h = input()
print("total pix: ")
print(int(_w) * int(_h))
# Out:
# width:
# 8
# height:
# 9
# total pix:
# 72

# %%
print("width: ")
_w = int (input())
print("height: ")
_h = int(input())
print("total pix: ")
print(int(_w) * int(_h))
# Out:
# width:
# 5
# height:
# 6
# total pix:
# 30

# %%
print("width: ")
_w = int (input())
print("height: ")
_h = int(input())
print("total pix: ")
print(int(_w) * int(_h))
if _w > _h:
  print(_w,"landscape orientation",_w)
elif _w == _h:
  print("square")
else:
  print(_h,"portrait orientation",_h)
  print(_h,"Portrait orientation",_h)
  """
  comrate9
  jgifhig
  jfij
  """
# Out:
# width:
# 1366
# height:
# 768
# total pix:
# 1049088
# 1366 landscape orientation 1366

# %%
"""_w,_h,_b = input("Enter values of w,h,b:").split()
print(w,_h,_b)"""
# Out:
# '_w,_h,_b = input("Enter values of w,h,b:").split()\nprint(w,_h,_b)'

# %%
name='Asian Nigga'
print(name.lower())
# Out:
# asian nigga

# %%
print("First Name")
_fn=input()
print("Last Name")
_ln=input()
_fullName=_fn+' '+_ln
print("Full Name")
print(_fn+' '+_ln)
print("Total Charecter without space:", len(_fn)+len(_ln))
print("Total Charecter with space:", len(_fullName))
print(_fullName.title())
# Out:
# First Name
# asian
# Last Name
# nigga
# Full Name
# asian nigga
# Total Charecter without space: 10
# Total Charecter with space: 11
# Asian Nigga

# %%
_1mill=1_000_000
print(_1mill)
# Out:
# 1000000

# %%
_loopText='Asian Nigga'
for iterator in range(10):
  print(_loopText)
# Out:
# Asian Nigga
# Asian Nigga
# Asian Nigga
# Asian Nigga
# Asian Nigga
# Asian Nigga
# Asian Nigga
# Asian Nigga
# Asian Nigga
# Asian Nigga

# %%
#check while loop
for iterator in range(1,11,2):
  print(iterator)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
demons=['beliul','behemoth','beelzebub', 'asmodius', 'satanas', 'lucifer']
for i in range(len(demons)):
  print(demons[i].title())
demons.append("barbatos") #add to the last
print("*****************")
for i in range(len(demons)):

  print(demons[i].title())
# Out:
# Beliul
# Behemoth
# Beelzebub
# Asmodius
# Satanas
# Lucifer
# *****************
# Beliul
# Behemoth
# Beelzebub
# Asmodius
# Satanas
# Lucifer
# Barbatos
